# %%
import duckdb as ddb

# %%
conn = ddb.connect()

# %%
ddb.sql('select 1')
# Out:
# ┌───────┐
# │   1   │
# │ int32 │
# ├───────┤
# │     1 │
# └───────┘

# %%
conn.sql('select 1').show()
print('hi')
# Out:
# ┌───────┐
# │   1   │
# │ int32 │
# ├───────┤
# │     1 │
# └───────┘
#
# hi

# %%
conn.sql("select 'a'").df()
# Out:
#   'a'
# 0   a

# %%
conn.execute('select "a"')
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 conn.execute('select "a"')
#
# BinderException: Binder Error: Referenced column "a" not found in FROM clause!
#
# LINE 1: select "a"
#                ^
