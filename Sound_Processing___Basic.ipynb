# %%
import soundfile as sf

# %%
import os

# %%
os.listdir('./data')
# Out:
# ['Alarm01.wav',
#  'bar_sample_data.csv',
#  'ent_2021.csv',
#  'FashionMNIST',
#  'hironic_2021.csv',
#  'Image_Processing_data',
#  'matplotlib_line_style.png',
#  'pytorch_basic_model.pth',
#  'sample_data.csv',
#  'trained_model.pt',
#  '바흐_첼로.mp3']

# %%
audio_data, samplerate = sf.read('./data/바흐_첼로.mp3')

# %%
duration = len(audio_data) / float(samplerate)

# %%
round(duration)
# Out:
# 129
